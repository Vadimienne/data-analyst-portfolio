# %%
import pandas as pd
from pathlib import Path


# функция для сохранения графиков

current_dir = Path.cwd()
PROJECT_ROOT = current_dir.parent

def save_chart(fig, filename: str, subfolder: str = 'charts'):
    path = PROJECT_ROOT / 'outputs'  / filename
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, dpi=150, bbox_inches='tight')


# читаем датасеты
DATA_PATH = PROJECT_ROOT / 'dataset'
tables = {
    'customers': 'olist_customers_dataset.csv', # клиенты
    'orders': 'olist_orders_dataset.csv', # заказы
    'items': 'olist_order_items_dataset.csv', # товары в заказах
    'payments': 'olist_order_payments_dataset.csv', # оплаты по заказам
    'reviews': 'olist_order_reviews_dataset.csv', # отзывы по заказам
    'products': 'olist_products_dataset.csv', # перечень товаров
    'sellers': 'olist_sellers_dataset.csv', # продавцы
    'geo': 'olist_geolocation_dataset.csv', # геолокации по зип-кодам
    'categories': 'product_category_name_translation.csv', # категории товаров
    'category_translations': 'product_category_name_translation.csv' # переводы названий категорий
}

data = {}
for name, filename in tables.items():
    filepath = DATA_PATH / filename
    if filepath.exists():
        data[name] = pd.read_csv(filepath)
        print(f"✅ {name}: {data[name].shape}")
    else:
        print(f"❌ Не найдено: {filename}")
# Out:
# ✅ customers: (99441, 5)
# ✅ orders: (99441, 8)
# ✅ items: (112650, 7)
# ✅ payments: (103886, 5)
# ✅ reviews: (99224, 7)
# ✅ products: (32951, 9)
# ✅ sellers: (3095, 4)
# ✅ geo: (1000163, 5)
# ✅ categories: (71, 2)
# ✅ category_translations: (71, 2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Берём заказы и фильтруем доставленные
delivered = data['orders'][data['orders']['order_status'] == 'delivered'].copy()

# Конвертируем даты 
date_cols = ['order_purchase_timestamp', 'order_approved_at', 
             'order_delivered_carrier_date', 'order_delivered_customer_date',
             'order_estimated_delivery_date']
for col in date_cols:
    if delivered[col].dtype == 'object':
        delivered[col] = pd.to_datetime(delivered[col])

# Считаем выручку по заказам
items = data['items'][['order_id', 'price']].copy()
items['revenue'] = items['price']
order_revenue = items.groupby('order_id')['revenue'].sum().reset_index()

# Джойним заказы + выручка
customer_data = delivered.merge(order_revenue, on='order_id', how='left')

# джоиним с customers для получения customer_unique_id
customer_data = customer_data.merge(
    data['customers'][['customer_id', 'customer_unique_id']],
    on='customer_id',
    how='left'
)

# Месяц заказа
customer_data['order_month'] = customer_data['order_purchase_timestamp'].dt.to_period('M')

# ищем месяц первой покупки каждого клиента
first_purchase = customer_data.groupby('customer_unique_id')['order_month'].min().reset_index()
first_purchase.columns = ['customer_unique_id', 'cohort_month']

# Джойним когорту обратно
customer_data = customer_data.merge(first_purchase, on='customer_unique_id')

# Возраст в месяцах (от первой покупки)
customer_data['age_months'] = (
    customer_data['order_month'] - customer_data['cohort_month']
).apply(lambda x: x.n)

# Фильтруем разумный возраст (убираем аномалии)
customer_data = customer_data[customer_data['age_months'] >= 0]
customer_data = customer_data[customer_data['age_months'] <= 24]



# Агрегируем выручку по когорте и возрасту
cohort_matrix = customer_data.groupby(['cohort_month', 'age_months'])['revenue'].sum().reset_index()

# Размер каждой когорты (сколько уникальных клиентов)
cohort_sizes = customer_data.groupby('cohort_month')['customer_unique_id'].nunique().reset_index()
cohort_sizes.columns = ['cohort_month', 'cohort_size']

# Merge и выручка на клиента
cohort_matrix = cohort_matrix.merge(cohort_sizes, on='cohort_month')
cohort_matrix['revenue_per_customer'] = cohort_matrix['revenue'] / cohort_matrix['cohort_size']

# строки = когорты, столбцы = возраст, значения = выручка на клиента
pivot_table = cohort_matrix.pivot_table(
    index='cohort_month',
    columns='age_months',
    values='revenue_per_customer',
    fill_value=0
)

# оставляем только когорты с данными хотя бы за 1 месяц
pivot_table = pivot_table[pivot_table.sum(axis=1) > 0]

# Фильтруем: оставляем только возрасты, где есть данные хотя бы по 5 когортам
min_cohorts_per_age = 5
valid_ages = [col for col in pivot_table.columns if (pivot_table[col] > 0).sum() >= min_cohorts_per_age]
if len(valid_ages) > 0:
    pivot_table = pivot_table[valid_ages]


plt.figure(figsize=(16, 10))

sns.heatmap(
    pivot_table,
    annot=True,
    fmt='.0f',
    cmap='YlOrRd',
    linewidths=0.5,
    linecolor='white',
    cbar_kws={'label': 'Выручка на клиента'},
    annot_kws={'size': 8}
)

plt.xlabel('Возраст клиента (месяцы с первой покупки)', fontsize=12, fontweight='bold', labelpad=10)
plt.ylabel('Когорта (месяц первой покупки)', fontsize=12, fontweight='bold', labelpad=10)
plt.title('Когортная матрица: выручка на клиента по когортам и возрасту', 
          fontsize=14, fontweight='bold', pad=20)

plt.yticks(rotation=0, fontsize=9)
plt.xticks(fontsize=10)
plt.tight_layout()

save_chart(plt.gcf(), 'cohort_heatmap.png', 'charts')
plt.show()

# %%
# почему получилась такая матрица
print(f"Уникальных клиентов: {customer_data['customer_unique_id'].nunique():,}")
print(f"Всего заказов: {len(customer_data):,}")
# Out:
# Уникальных клиентов: 93,358
# Всего заказов: 96,478

# %%
# c LTV не получилось, посчитаем AOV

# Берём доставленные заказы
delivered = data['orders'][data['orders']['order_status'] == 'delivered'].copy()

# Конвертируем даты
date_cols = ['order_purchase_timestamp', 'order_approved_at', 
             'order_delivered_carrier_date', 'order_delivered_customer_date']
for col in date_cols:
    if delivered[col].dtype == 'object':
        delivered[col] = pd.to_datetime(delivered[col])

# Считаем выручку по заказам
items = data['items'][['order_id', 'price']].copy()
items['revenue'] = items['price']
order_revenue = items.groupby('order_id')['revenue'].sum().reset_index()

# Джойним
orders_with_revenue = delivered.merge(order_revenue, on='order_id', how='left')

# Когорта = месяц заказа (не клиента!)
orders_with_revenue['order_month'] = orders_with_revenue['order_purchase_timestamp'].dt.to_period('M')

# Агрегация по месяцу заказа
aov_by_cohort = orders_with_revenue.groupby('order_month').agg(
    order_count=('order_id', 'count'),
    total_revenue=('revenue', 'sum'),
    aov=('revenue', 'mean'),
    median_revenue=('revenue', 'median'),
    std_revenue=('revenue', 'std')
).reset_index()


aov_by_cohort = aov_by_cohort[aov_by_cohort['order_count'] > 700] # исчключаем мусорные месяцы

# считаем тренд 
aov_by_cohort['month_num'] = range(len(aov_by_cohort))
z = np.polyfit(aov_by_cohort['month_num'], aov_by_cohort['aov'], 1)
aov_by_cohort['trend'] = np.poly1d(z)(aov_by_cohort['month_num'])


# график
plt.figure(figsize=(14, 7))
plt.bar(aov_by_cohort['order_month'].astype(str), aov_by_cohort['aov'], 
        color='#3498db', alpha=0.7, label='AOV по месяцу')
plt.plot(aov_by_cohort['order_month'].astype(str), aov_by_cohort['trend'], 
         color='#e74c3c', linewidth=2.5, label=f'Тренд: {z[0]:+.2f}R$/мес')

plt.xlabel('Месяц заказа', fontsize=11)
plt.ylabel('Средняя ценность заказа (AOV), R$', fontsize=11)
plt.title('Тренд AOV по когортам заказов', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(axis='y', alpha=0.3, linestyle='--')
plt.tight_layout()
save_chart(plt.gcf(), 'aov_trend.png', 'charts')
plt.show()

# Выводы
avg_aov = aov_by_cohort['aov'].mean()
first_aov = aov_by_cohort['aov'].iloc[0]
last_aov = aov_by_cohort['aov'].iloc[-1]
print(f"\nКлючевые метрики:")
print(f" Средний AOV: R${avg_aov:.2f}")
print(f" Изменение за период: R${first_aov:.2f} → R${last_aov:.2f} ({(last_aov/first_aov-1)*100:+.1f}%)")
print(f" Тренд: {z[0]:+.2f}R$ в месяц")
# Out:
# Ключевые метрики:
#  Средний AOV: R$138.09
#  Изменение за период: R$149.06 → R$132.04 (-11.4%)
#  Тренд: -0.27R$ в месяц
